# %% [markdown]
# # Tracking Dataset Processing
#
# This notebook can be used to load, evaluate, compare, refine and export hand-labeled tracking datasets
#
# *(Data must be annotated with the blender **MotionExportAddon.py** script or follow the convention of individual CSV files per tracked animal with explicit frame numbers)*
#
# First, let's load some packages and a few essential import / export functions from **Antrax_base.py**

# %%
import numpy as np
import cv2
import csv
import os
import math
import time
import random
import matplotlib.pyplot as plt
from sklearn.utils import shuffle

# now for the file management fucntions
from Antrax_base import import_tracks, display_video, get_exact_frame, extractPatches, display_patches, sortByDistance

# %% [markdown]
# To get more information on how each function works, you can simply type it out followed by a question mark to display its docstring below:

# %%
# Exp: Show the docstring of "import_tracks" by uncommenting the next line
import_tracks?

# %% [markdown]
# Now specify the **location** of all **export folders** of tracks you wish to analyse. Simply add the folder path to the **export_paths** array and the location of the annotated video file.

# %%
export_paths = ["C:/export/rose_petals_right"]
video = "I:/FELIX_dark_market/Data/ebay_data_new/rose_petals_right.avi"

# enter the number of annotated frames:
tracked_frames = 1000

# now we can load the captured video file and display it
cap = cv2.VideoCapture(video)

# check the number of frames of the imported video file
numFramesMax = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print("The imported clip:", video, "has a total of",numFramesMax ,"frames.\n")

# now let's load all tracks listed in the export_paths
tracks = []
for folder in export_paths:
    # You can export all tracks into a single .csv file by setting "export=True"
    tracks.append(import_tracks(folder, numFramesMax, export=True))
    
    # The following function is used to display the tracks you imported.
    # You can press "q" while hovering over the displayed video to exit.
    print("\nDisplaying tracks loaded from:", folder)
    display_video(cap, tracks[-1], show=(0, tracked_frames), scale=0.3)
# Out:
# The imported clip: rec_climate_chamber_sub_colony_base_10000_frames.mp4 has a total of 10000 frames.
#
# importing tracks...
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.000.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.001.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.002.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.003.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.004.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.005.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.006.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.007.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.008.csv  with 164 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.009.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.010.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.011.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.012.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.013.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.014.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.015.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.016.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.017.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.018.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.019.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.020.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.021.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.022.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.023.csv  with 537 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.024.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.025.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.026.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.027.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.028.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.029.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.030.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.031.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.032.csv  with 827 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.033.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.034.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.035.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.036.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.037.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.038.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.039.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.040.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.041.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.042.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.043.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.044.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.045.csv  with 770 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.046.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.047.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.048.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.049.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.050.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.051.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.052.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.053.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.054.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.055.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.056.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.057.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.058.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.059.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.060.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.061.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.062.csv  with 19 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.064.csv  with 798 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.065.csv  with 102 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.066.csv  with 932 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.067.csv  with 204 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.068.csv  with 705 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.069.csv  with 265 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.070.csv  with 774 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.071.csv  with 533 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.072.csv  with 188 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.073.csv  with 268 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.074.csv  with 49 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.075.csv  with 26 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.076.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.077.csv  with 356 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.078.csv  with 653 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.079.csv  with 545 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.080.csv  with 147 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.081.csv  with 68 points.
#
# Successfully combined the tracks of 81 individuals for training and display!
#
# Displaying tracks loaded from: export_base_FABI
#
# Displaying tracked footage!
# press 'q' to end display
#
# Reached last frame of specified video or ended by user input.
#
# importing tracks...
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.000.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.001.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.002.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.003.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.004.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.005.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.006.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.007.csv  with 994 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.008.csv  with 1000 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.009.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.010.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.011.csv  with 877 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.012.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.013.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.014.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.015.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.016.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.017.csv  with 971 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.018.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.019.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.020.csv  with 512 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.021.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.022.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.023.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.024.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.025.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.026.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.027.csv  with 787 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.028.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.029.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.030.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.031.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.032.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.033.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.034.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.035.csv  with 748 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.036.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.037.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.038.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.039.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.040.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.041.csv  with 191 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.042.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.043.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.044.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.045.csv  with 926 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.046.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.047.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.048.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.049.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.050.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.051.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.052.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.053.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.054.csv  with 131 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.055.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.056.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.057.csv  with 291 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.058.csv  with 219 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.059.csv  with 510 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.060.csv  with 701 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.061.csv  with 251 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.062.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.063.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.064.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.065.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.066.csv  with 1001 points.
# imported exportrec_climate_chamber_sub_colony_base_10000_frames_Track.067.csv  with 1001 points.
#
# Successfully combined the tracks of 68 individuals for training and display!
#
# Displaying tracks loaded from: export_base_NAT
#
# Displaying tracked footage!
# press 'q' to end display
#
# Reached last frame of specified video or ended by user input.

# %% [markdown]
# Next, we'll plot the imported trajectories from each subfolder.

# %%
# get the resolution of the video file to automatically adjust the axis limits of the plot
resolution = [int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))]

def plot_tracks(tracks, title=""):
    # replace all zeros with None before plotting
    tracks = tracks.astype(float)
    tracks[tracks == 0] = None

    for track in range(int((tracks.shape[-1] - 1) / 2)):
        plt.plot(tracks[:tracked_frames,int(track*2 + 1)],tracks[:tracked_frames,int(track*2 + 2)])

        plt.title(title)    
        plt.xlabel("X axis [px]")   
        plt.ylabel("Y axis [px]")
        plt.xlim(0,resolution[0])
        plt.ylim(0,resolution[1])

    plt.show()
    
# plot all tracks    
for count, annotator in enumerate(tracks):
    num_tracks = int((annotator.shape[-1] - 1)/2)  
    plot_tracks(tracks=annotator,title="all tracks of " + export_paths[count])

# %% [markdown]
# Now we'll match the **tracks** of **all annotators** based on their **proximity**. We'll iterate through all tracks of the first annotator and compute a similirity score based on the distance of each tracked instance, ignoring zeros.

# %%
def get_similarity(track_1, track_2, matching_threshold=50):
    # here we use the pixel distance as a metric of similarity
    # the lower the pixel distance, thus similarity value, the higher the liklihood of two track belonging to the same ID
    combined_distance = []
    track_1 = track_1.astype(float)
    track_2 = track_2.astype(float)
    for frame, coords in enumerate(track_1):
        if not np.array_equal(track_1[frame],[0,0]) and not np.array_equal(track_2[frame],[0,0]):
            combined_distance.append(np.sqrt(np.power(track_1[frame,0] - track_2[frame,0],2) +
                                             np.power(track_1[frame,1] - track_2[frame,1],2)))
            
    # now compute the similarity as the mean distance between the two tracks
    if combined_distance:
        similarity = np.round(np.mean(combined_distance), decimals=3)
    else:
        similarity = matching_threshold
    return similarity


def match_tracks(tracks_a, tracks_b):
    num_tracks_a = int((tracks_a.shape[1] - 1)/2)
    num_tracks_b = int((tracks_b.shape[1] - 1)/2)
    similarities = np.empty([num_tracks_a, num_tracks_b], dtype=float)
    print("Similarity grid shape:", similarities.shape, "\n")
    print("Computing similarities...")

    # compare all tracks of 2 annotators at a time and match them based on their mean euclidean distance
    for a in range(similarities.shape[0]):
        for b in range (similarities.shape[1]):
            similarities[a,b] = get_similarity(track_1=tracks_a[:tracked_frames,a*2 + 1:a*2 + 3],
                                               track_2=tracks_b[:tracked_frames,b*2 + 1:b*2 + 3],
                                               matching_threshold = matching_threshold)

    # record the indices of all likely matches and unmatched tracks
    matched = []
    unmatched_a = []
    unmatched_b = np.arange(num_tracks_b)

    for track_a, track_a_similarities in enumerate(similarities):
        sim_max = np.argmin(track_a_similarities[np.nonzero(track_a_similarities)])
        if track_a_similarities[sim_max] < matching_threshold:
            matched.append([track_a,sim_max])
            unmatched_b[sim_max] = 0
            print("Track", track_a, "most likely corresponds to Track", sim_max,
                  "with a mean euclidean distance [px] of", track_a_similarities[sim_max])
        else:
            unmatched_a.append(track_a)
            print("Track", track_a, "has no likely match.")

    # show list of matched tracks        
    print("\nmatched:\n",matched,"\n")

    if len(unmatched_a) > 0:
        print("Unmatched tracks of",export_paths[0],": \n",unmatched_a,"\n")
    else:
        print("All tracks of",export_paths[0], "have been matched!\n")

    # create the final list of unmatched_b tracks
    unmatched_b = unmatched_b[unmatched_b != 0]
    if len(unmatched_b) > 0:
        print("Unmatched tracks of",export_paths[1],": \n",unmatched_b,"\n")
    else:
        print("All tracks of",export_paths[1], "have been matched!\n")

    return matched, unmatched_a, unmatched_b


def generate_ground_truth(tracks_a, tracks_b, matches, unmatched_a, unmatched_b, num_frames, 
                          iteration=0, ignore_unmatched=False):
    # create array of the size of (num_frames x (frame + all_tracks(x,y)))
    ground_truth = np.zeros([num_frames, 1 + 2 * (len(matches) + len(unmatched_a) + len(unmatched_b))])
    
    # add frame numers to the first column
    frames = np.arange(1,num_frames + 1)
    
    ground_truth[:,0] = frames
    
    if iteration == 0:
        print("Initial combination of tracks. All are weighted equally")
    else: 
        print("Iteration:", iteration)
        print("Additional tracks contribute with 1/"+ str(iteration + 2),"weight.\n")
    
    # now compute the weighted average for every matching track
    for count, match in enumerate(matches):
        for frame in range(ground_truth.shape[0]):
            pos_a_x, pos_a_y = tracks_a[frame , 2 * match[0] + 1 : 2 * match[0] + 3]
            pos_b_x, pos_b_y = tracks_b[frame , 2 * match[1] + 1 : 2 * match[1] + 3]
            
            pos_sum_x = pos_a_x * (1 + iteration) + pos_b_x
            pos_sum_y = pos_a_y * (1 + iteration) + pos_b_y
            
            if pos_a_x != 0 and pos_b_x != 0:
                ground_truth[frame,count * 2 + 1] = pos_sum_x / (2 + iteration)
            else:
                # only compute the average if both values are non-zero
                # If one value is zero, only the other should contribute to the track
                ground_truth[frame,count * 2 + 1] = pos_sum_x
                
            # repeat for the y-axis
            
            if pos_a_y != 0 and pos_b_y != 0:
                ground_truth[frame,count * 2 + 2] = pos_sum_y / (2 + iteration)
            else:
                # only compute the average if both values are non-zero
                # If one value is zero, only the other should contribute to the track
                ground_truth[frame,count * 2 + 2] = pos_sum_y
                
    # add the remaining unmatched_a tracks
    if len(unmatched_a) > 0:
        for count, unmatched in enumerate(unmatched_a):
            ground_truth[:,(count + len(matches)) * 2 + 1: (count + len(matches)) * 2 + 3] = tracks_a[
                :tracked_frames,unmatched * 2 + 1 : unmatched * 2 + 3]
    
    # add the remaining unmatched_b tracks
    if len(unmatched_b) > 0:
        for count, unmatched in enumerate(unmatched_b):
            ground_truth[:,(count + len(unmatched_a) + len(matches)) * 2 + 1: 
                         (count + len(unmatched_a) + len(matches)) * 2 + 3] = tracks_b[
                :tracked_frames,unmatched * 2 + 1 : unmatched * 2 + 3]
    
    return ground_truth

# %% [markdown]
# After computing **likely matching tracks** we can now combine them into **ground truth tracks**, which are a weighted average of all matching tracks. **Unmatched tracks** are added without modification. Then, we iteratively compare the current ground truth to further annotators.

# %%
# adjust the matching threshold according to the track quality and resolution of the tracked footage
matching_threshold = 50

# compute a grid of similarities between all tracks

matched, unmatched_a, unmatched_b = match_tracks(tracks_a = tracks[0], tracks_b = tracks[1])
# Out:
# Similarity grid shape: (81, 68)
#
# Computing similarities...
# Track 0 most likely corresponds to Track 63 with a mean euclidean distance [px] of 1.779
# Track 1 most likely corresponds to Track 56 with a mean euclidean distance [px] of 1.957
# Track 2 most likely corresponds to Track 55 with a mean euclidean distance [px] of 3.109
# Track 3 most likely corresponds to Track 1 with a mean euclidean distance [px] of 2.748
# Track 4 most likely corresponds to Track 18 with a mean euclidean distance [px] of 7.322
# Track 5 most likely corresponds to Track 62 with a mean euclidean distance [px] of 2.997
# Track 6 most likely corresponds to Track 2 with a mean euclidean distance [px] of 4.584
# Track 7 most likely corresponds to Track 7 with a mean euclidean distance [px] of 5.83
# Track 8 most likely corresponds to Track 54 with a mean euclidean distance [px] of 6.336
# Track 9 most likely corresponds to Track 10 with a mean euclidean distance [px] of 6.286
# Track 10 most likely corresponds to Track 6 with a mean euclidean distance [px] of 2.405
# Track 11 most likely corresponds to Track 13 with a mean euclidean distance [px] of 4.766
# Track 12 most likely corresponds to Track 9 with a mean euclidean distance [px] of 3.028
# Track 13 most likely corresponds to Track 66 with a mean euclidean distance [px] of 2.132
# Track 14 most likely corresponds to Track 64 with a mean euclidean distance [px] of 1.288
# Track 15 most likely corresponds to Track 4 with a mean euclidean distance [px] of 5.405
# Track 16 most likely corresponds to Track 5 with a mean euclidean distance [px] of 4.744
# Track 17 most likely corresponds to Track 8 with a mean euclidean distance [px] of 5.238
# Track 18 most likely corresponds to Track 12 with a mean euclidean distance [px] of 6.805
# Track 19 most likely corresponds to Track 14 with a mean euclidean distance [px] of 7.932
# Track 20 most likely corresponds to Track 15 with a mean euclidean distance [px] of 4.322
# Track 21 most likely corresponds to Track 17 with a mean euclidean distance [px] of 7.135
# Track 22 most likely corresponds to Track 16 with a mean euclidean distance [px] of 5.408
# Track 23 most likely corresponds to Track 20 with a mean euclidean distance [px] of 5.389
# Track 24 most likely corresponds to Track 21 with a mean euclidean distance [px] of 5.174
# Track 25 most likely corresponds to Track 22 with a mean euclidean distance [px] of 3.062
# Track 26 most likely corresponds to Track 19 with a mean euclidean distance [px] of 5.742
# Track 27 most likely corresponds to Track 3 with a mean euclidean distance [px] of 7.451
# Track 28 most likely corresponds to Track 24 with a mean euclidean distance [px] of 5.914
# Track 29 most likely corresponds to Track 23 with a mean euclidean distance [px] of 4.243
# Track 30 most likely corresponds to Track 25 with a mean euclidean distance [px] of 2.471
# Track 31 most likely corresponds to Track 26 with a mean euclidean distance [px] of 4.622
# Track 32 most likely corresponds to Track 27 with a mean euclidean distance [px] of 9.334
# Track 33 most likely corresponds to Track 29 with a mean euclidean distance [px] of 5.247
# Track 34 most likely corresponds to Track 30 with a mean euclidean distance [px] of 2.774
# Track 35 most likely corresponds to Track 28 with a mean euclidean distance [px] of 8.593
# Track 36 most likely corresponds to Track 38 with a mean euclidean distance [px] of 6.485
# Track 37 most likely corresponds to Track 65 with a mean euclidean distance [px] of 2.439
# Track 38 most likely corresponds to Track 31 with a mean euclidean distance [px] of 6.572
# Track 39 most likely corresponds to Track 32 with a mean euclidean distance [px] of 5.756
# Track 40 most likely corresponds to Track 37 with a mean euclidean distance [px] of 4.297
# Track 41 most likely corresponds to Track 34 with a mean euclidean distance [px] of 3.004
# Track 42 most likely corresponds to Track 42 with a mean euclidean distance [px] of 3.154
# Track 43 most likely corresponds to Track 33 with a mean euclidean distance [px] of 5.311
# Track 44 most likely corresponds to Track 45 with a mean euclidean distance [px] of 7.634
# Track 45 most likely corresponds to Track 35 with a mean euclidean distance [px] of 5.288
# Track 46 most likely corresponds to Track 43 with a mean euclidean distance [px] of 2.853
# Track 47 most likely corresponds to Track 39 with a mean euclidean distance [px] of 3.644
# Track 48 most likely corresponds to Track 36 with a mean euclidean distance [px] of 3.964
# Track 49 most likely corresponds to Track 44 with a mean euclidean distance [px] of 5.341
# Track 50 most likely corresponds to Track 47 with a mean euclidean distance [px] of 3.232
# Track 51 most likely corresponds to Track 46 with a mean euclidean distance [px] of 2.326
# Track 52 most likely corresponds to Track 40 with a mean euclidean distance [px] of 2.812
# Track 53 most likely corresponds to Track 0 with a mean euclidean distance [px] of 0.665
# Track 54 most likely corresponds to Track 49 with a mean euclidean distance [px] of 2.875
# Track 55 most likely corresponds to Track 50 with a mean euclidean distance [px] of 4.54
# Track 56 most likely corresponds to Track 52 with a mean euclidean distance [px] of 8.127
# Track 57 most likely corresponds to Track 51 with a mean euclidean distance [px] of 4.257
# Track 58 most likely corresponds to Track 48 with a mean euclidean distance [px] of 3.937
# Track 59 most likely corresponds to Track 67 with a mean euclidean distance [px] of 1.257
# Track 60 most likely corresponds to Track 53 with a mean euclidean distance [px] of 3.868
# Track 61 has no likely match.
# Track 62 has no likely match.
# Track 63 most likely corresponds to Track 60 with a mean euclidean distance [px] of 4.17
# Track 64 has no likely match.
# Track 65 most likely corresponds to Track 11 with a mean euclidean distance [px] of 7.876
# Track 66 has no likely match.
# Track 67 most likely corresponds to Track 59 with a mean euclidean distance [px] of 19.889
# Track 68 has no likely match.
# Track 69 most likely corresponds to Track 61 with a mean euclidean distance [px] of 8.157
# Track 70 has no likely match.
# Track 71 has no likely match.
# Track 72 most likely corresponds to Track 41 with a mean euclidean distance [px] of 5.989
# Track 73 has no likely match.
# Track 74 has no likely match.
# Track 75 has no likely match.
# Track 76 has no likely match.
# Track 77 most likely corresponds to Track 58 with a mean euclidean distance [px] of 4.026
# Track 78 most likely corresponds to Track 57 with a mean euclidean distance [px] of 5.638
# Track 79 has no likely match.
# Track 80 has no likely match.
#
# matched:
#  [[0, 63], [1, 56], [2, 55], [3, 1], [4, 18], [5, 62], [6, 2], [7, 7], [8, 54], [9, 10], [10, 6], [11, 13], [12, 9], [13, 66], [14, 64], [15, 4], [16, 5], [17, 8], [18, 12], [19, 14], [20, 15], [21, 17], [22, 16], [23, 20], [24, 21], [25, 22], [26, 19], [27, 3], [28, 24], [29, 23], [30, 25], [31, 26], [32, 27], [33, 29], [34, 30], [35, 28], [36, 38], [37, 65], [38, 31], [39, 32], [40, 37], [41, 34], [42, 42], [43, 33], [44, 45], [45, 35], [46, 43], [47, 39], [48, 36], [49, 44], [50, 47], [51, 46], [52, 40], [53, 0], [54, 49], [55, 50], [56, 52], [57, 51], [58, 48], [59, 67], [60, 53], [63, 60], [65, 11], [67, 59], [69, 61], [72, 41], [77, 58], [78, 57]]
#
# Unmatched tracks of export_base_FABI :
#  [61, 62, 64, 66, 68, 70, 71, 73, 74, 75, 76, 79, 80]
#
# All tracks of export_base_NAT have been matched!

# %%
gt = generate_ground_truth(tracks_a=tracks[0], tracks_b=tracks[1], matches=matched, unmatched_a=unmatched_a, 
                      unmatched_b=unmatched_b, num_frames=tracked_frames, iteration=0)

print("Generated a total of",int((gt.shape[-1] - 1) / 2),"ground truth tracks.")

display_video(cap, gt, show=(0, tracked_frames - 2), scale=0.3)

# plot resulting ground truth tracks
plot_tracks(tracks=gt, title="all ground truth tracks")
# Out:
# Initial combination of tracks. All are weighted equally
# Generated a total of 81 ground truth tracks.
#
# Displaying tracked footage!
# press 'q' to end display
#
# Reached last frame of specified video or ended by user input.

# %% [markdown]
# The generated **ground truth tracks** can now be exported.

# %%
def export_tracks(tracks,path="ground_truth"):
    tracks = tracks.astype(int)
    np.savetxt(path + ".csv", tracks, delimiter=",")
    
    print("Exported tracks successfully to", path + ".csv")
    
export_tracks(tracks=gt, path="ground_truth_" + video.split(".")[0])
# Out:
# Exported tracks successfully to ground_truth_rec_climate_chamber_sub_colony_base_10000_frames.csv

# %% [markdown]
# We can also **import** existing ground truth files for evaluation or to add further annotators. When adding additional annotators, make sure to correctly set the iteration to weigh the influence of further tracks correctly.

# %%
def import_ground_truth(path):
    tracks = np.loadtxt(path, delimiter=",")
    tracks = tracks.astype(int)
    
    print("Imported tracks successfully from", path)
    
    return tracks

new_gt = import_ground_truth(path="ground_truth_rec_climate_chamber_sub_colony_base_10000_frames.csv")
# Out:
# Imported tracks successfully from ground_truth_rec_climate_chamber_sub_colony_base_10000_frames.csv

# %%
def get_derivative(tracks, time_step=1/30):
    tracks_der = np.zeros([tracks.shape[0],int((tracks.shape[1] - 1)/2)])
    # convert tracks to float array
    tracks_der = tracks_der.astype(float)
    
    num_tracks = int((tracks.shape[1] - 1)/2)  
    num_timeSteps = tracks.shape[0]
    
    print("Computing derivative for", num_tracks, "tracks...")
    for track in range(num_tracks):
        track_der = []
        for t in range(num_timeSteps - 1):
            if tracks[t + 1,track * 2 + 1] != 0 and tracks[t + 1,track * 2 + 2] != 0:   
                tracks_der[t,track] = np.sqrt((tracks[t + 1,track * 2 + 1] - tracks[t,track * 2 + 1])**2 + 
                                              (tracks[t + 1,track * 2 + 2] - tracks[t,track * 2 + 2])**2) / time_step
            
    return tracks_der

def apply_moving_average(tracks, samples=3, padding_mode='valid'):
    tracks_ma = np.copy(tracks)
    num_tracks = int((tracks.shape[1] - 1)/2)  
    num_timeSteps = tracks.shape[0]

    print("Applying moving average of size", samples, "to", num_tracks, "tracks...")
    for t in range(num_tracks):
        # apply smoothing only to areas where tracked subject is in view
        # therefore, all zero entries must be ignored
        track_temp_x = tracks[:,t * 2 + 1]
        track_temp_y = tracks[:,t * 2 + 2]
        
        nonzeroind = np.nonzero(track_temp_x)[0]
        
        track_x = np.convolve(track_temp_x[nonzeroind[0]:nonzeroind[-1]-samples], np.ones(samples)/samples, mode=padding_mode)
        track_y = np.convolve(track_temp_y[nonzeroind[0]:nonzeroind[-1]-samples], np.ones(samples)/samples, mode=padding_mode)
        
        tracks_ma[nonzeroind[0] + math.floor(samples/2):nonzeroind[-1] - math.ceil(samples/2) - samples + 1, t * 2 + 1] = track_x
        tracks_ma[nonzeroind[0] + math.floor(samples/2):nonzeroind[-1] - math.ceil(samples/2) - samples + 1, t * 2 + 2] = track_y    
        
    # add back zeros
    tracks_ma = tracks_ma.astype(int)
    return tracks_ma

# %%
tracks_smoothed = apply_moving_average(new_gt, samples=9)
tracks_velocity = get_derivative(tracks_smoothed)

# plot smoothed ground truth tracks
plot_tracks(tracks=tracks_smoothed, title="smoothed ground truth tracks")

# plot velocity profile of example ground truth tracks
plt.plot(tracks_velocity[:,5:10])
plt.title("example velocity profiles of smoothed tracks")
plt.xlabel("time [s]")
plt.ylabel("velocity [px/s]")
plt.ylim(0,600)
plt.show()
# Out:
# Applying moving average of size 9 to 81 tracks...
# Computing derivative for 81 tracks...

# %%
# plot heatmap of ground truth tracks
# first, combine all traccks into an array of X,Y coords
tracks_compressed = np.array([], dtype=np.int64).reshape(0,2)
for track in range(int((new_gt.shape[1] - 1)/2)):
    tracks_compressed = np.vstack((tracks_compressed,new_gt[:,track * 2 + 1 : track * 2 + 3]))
    
# now remove all zero entries from the array to prevent the 0 bin from over saturating the plot
tracks_compressed = tracks_compressed[~np.all(tracks_compressed == 0, axis=1)]
    
heatmap, xedges, yedges = np.histogram2d(tracks_compressed[:,0], tracks_compressed[:,1], 
                                         bins=(int(resolution[0]/100),int(resolution[1]/100)),
                                         range=[[0,resolution[0]],[0,resolution[1]]])
extent = [xedges[0], xedges[-1], yedges[0], yedges[-1]]

from matplotlib.image import NonUniformImage

fig, ax = plt.subplots()

im = NonUniformImage(ax, interpolation='bilinear', extent=extent)
xcenters = (xedges[:-1] + xedges[1:]) / 2
ycenters = (yedges[:-1] + yedges[1:]) / 2
im.set_data(xcenters, ycenters, heatmap.T)
ax.images.append(im)

plt.xlabel("X axis [px]")   
plt.ylabel("Y axis [px]")
plt.xlim(0,resolution[0])
plt.ylim(0,resolution[1])
plt.title("heatmap of ground truth tracks")
plt.show()
